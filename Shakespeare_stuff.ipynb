# %% [markdown]
# <a href="https://colab.research.google.com/github/niyathikukkapalli/mini-llm/blob/main/Shakespeare_stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch # imports pytorch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, num_heads, d_model):
        super().__init__()
        self.Wq = nn.Linear(d_model, d_model)
        self.Wk = nn.Linear(d_model, d_model)
        self.Wv = nn.Linear(d_model, d_model)
        self.Wo = nn.Linear(d_model, d_model)
        self.num_heads = num_heads
    def forward(self, x):
        batch_size, seq_len, d_model = x.shape[0], x.shape[1], x.shape[2]
        num_heads, d_head = self.num_heads, d_model // self.num_heads
        Q = self.Wq(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1, 2) #(batch_size, seq_len, d_model) -> (batch_size, num_heads, seq_len, d_head)
        K = self.Wk(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1, 2) #(batch_size, seq_len, d_model) -> (batch_size, num_heads, seq_len, d_head)
        V = self.Wv(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1, 2) #(batch_size, seq_len, d_model) -> (batch_size, num_heads, seq_len, d_head)

        mask = torch.ones(seq_len, seq_len, device=x.device, dtype=torch.bool)
        mask = torch.tril(mask)

        attn_scores = Q @ K.transpose(2, 3) / d_head**0.5
        attn_scores = torch.masked_fill(attn_scores, ~mask, -1e9)
        attn_weights = F.softmax(attn_scores, dim=-1)
        context = attn_weights @ V

        context = context.transpose(1, 2).reshape(batch_size, seq_len, d_model)
        x = self.Wo(context)
        return x



class FFN(nn.Module):
    def __init__(self, d_model):
        super().__init__()
        self.W1 = nn.Linear(d_model, 4 * d_model)
        self.W2 = nn.Linear(4 * d_model, d_model)
    def forward(self, x):
        x = F.gelu(self.W1(x))
        x = self.W2(x)
        return x

class TransformerBlock(nn.Module):
    def __init__(self, num_heads, d_model):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.mhsa = MultiHeadSelfAttention(num_heads, d_model)
        self.ln2 = nn.LayerNorm(d_model)
        self.ffn = FFN(d_model)
    def forward(self, x):
        x = x + self.mhsa(self.ln1(x))
        x = x + self.ffn(self.ln2(x))
        return x

class Transformer(nn.Module):
    def __init__(self, vocab_size, d_model, n_layers, num_heads, seq_len):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_embedding = nn.Embedding(seq_len, d_model)
        self.transformer_blocks = nn.ModuleList([TransformerBlock(num_heads, d_model) for _ in range(n_layers)])
        self.ln = nn.LayerNorm(d_model)
        self.out_proj = nn.Linear(d_model, vocab_size)
    def forward(self, x):
        seq_len = x.shape[1]
        embs = self.embedding(x)
        pos_embs = self.pos_embedding(torch.arange(seq_len, device=x.device, dtype=torch.long))
        x = embs + pos_embs
        for transformer_block in self.transformer_blocks:
            x = transformer_block(x)
        x = self.ln(x)
        x = self.out_proj(x)
        return x

# %%
from torch.utils.data import Dataset, DataLoader

vocab_size = 65
d_model = 96
n_layers = 4
num_heads = 4
seq_len = 32
batch_size = 16
lr=1e-4
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"

with open("/content/sample_data/shakespeare.txt") as f:
    text_corpus = f.read()

char2token = {c:i for i, c in enumerate(sorted(set(text_corpus)))}
token2char = {i:c for c, i in char2token.items()}

def tokenize(string):
    return [char2token[c] for c in string]
def decode(tokens):
    return "".join([token2char[token] for token in tokens])

text_tokens = tokenize(text_corpus)

labels = text_tokens[1:]
inputs = text_tokens[:-1]
trunc_len = len(inputs) - len(inputs) % seq_len
labels = torch.tensor(labels[:trunc_len]).reshape(-1, seq_len)
inputs = torch.tensor(inputs[:trunc_len]).reshape(-1, seq_len)

class ShakespeareDataset(Dataset):
    def __init__(self, inputs, labels):
        super().__init__()
        self.inputs = inputs
        self.labels = labels
    def __len__(self):
        return len(self.inputs)
    def __getitem__(self, idx):
        return self.inputs[idx], self.labels[idx]

dataset = ShakespeareDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

model = Transformer(vocab_size, d_model, n_layers, num_heads, seq_len).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
loss_fn = nn.CrossEntropyLoss()

@torch.no_grad()
def generate(prompt, num_tokens):
    tokens = tokenize(prompt)
    tokens = torch.tensor([tokens], device=device) #(batch_dim, len_of_seq)
    for _ in range(num_tokens):
        logits = model(tokens[:, -seq_len:]) #(batch_dim, seq_len, vocab_size)
        probs = F.softmax(logits, dim=-1)[:, -1, :] #(batch_dim, seq_len, vocab_size) -> (batch_dim, vocab_size)
        next_token = torch.multinomial(probs, num_samples=1) #(batch_dim, 1)
        tokens = torch.cat([tokens, next_token], dim=-1)
    return decode(tokens[0].cpu().tolist())


for epoch in range(num_epochs):
    for batch_idx, batch in enumerate(dataloader):
        if batch_idx % 500 == 0:
            print("\n" + generate(prompt="\n", num_tokens=1000) + "\n")
        inputs, labels = batch[0].to(device), batch[1].to(device)
        logits = model(inputs) #inputs: (batch_size, seq_len) -> (batch_size, seq_len, vocab_size); labels: (batch_size, seq_len)
        loss = loss_fn(logits.reshape(-1, vocab_size), labels.reshape(-1))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print(f"Epoch {epoch}, batch {batch_idx}: loss={loss.item()}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# DUKE OF ARH:
# Our, but heaves, befole house?
#
# HENRY:
# Nay, Proclediess' no death ble! leef; Sorter.
#
# LUCIO:
# Govice an what me?
#
# OKENE:
# But of God TyMEan:
# Richard life, Parition in!
#
# SIe 'Tis are sluck.
#
# HROMER:
# Ayoring find fortck, beye broved jealies
# For the vain of my friend; preset'
# And of that of your been no chince,
# This both within thy father streath!
#
# Servant Lord, that, I two with I rep,
# HoLe matters I till coes of sprose affalled vioullit him sweet st the kneebugh
# I will men: at shall feel to mysent
# Where any will her propleing
# And the ablack mader'd but I be hope turt entil thy caush chasbenger uple a dive
# To were'! thou had be then pours--
#
# GLUCKENt:
# To have:
# I bein me now, all; I what worth he dew.
#
# TRANxtranced her I have not all kins, far
# all stripproud that fights pind
# Teccard appartience.
#
# SICINIU:
# But my god came man piration.
#
# First Might, can him man thy cast of things;
# Of, those heards he may casingtless
# With his way! as a not fares then,
# Ony now Edward got man of t
#
# Epoch 8, batch 500: loss=1.6489136219024658
# Epoch 8, batch 510: loss=1.5581622123718262
# Epoch 8, batch 520: loss=1.5683047771453857
# Epoch 8, batch 530: loss=1.7121632099151611
# Epoch 8, batch 540: loss=1.649611473083496
# Epoch 8, batch 550: loss=1.7051661014556885
# Epoch 8, batch 560: loss=1.6207146644592285
# Epoch 8, batch 570: loss=1.54361093044281
# Epoch 8, batch 580: loss=1.6156673431396484
# Epoch 8, batch 590: loss=1.6893069744110107
# Epoch 8, batch 600: loss=1.6300158500671387
# Epoch 8, batch 610: loss=1.5232949256896973
# Epoch 8, batch 620: loss=1.7041373252868652
# Epoch 8, batch 630: loss=1.6771266460418701
# Epoch 8, batch 640: loss=1.6089138984680176
# Epoch 8, batch 650: loss=1.6413075923919678
# Epoch 8, batch 660: loss=1.6087017059326172
# Epoch 8, batch 670: loss=1.6238462924957275
# Epoch 8, batch 680: loss=1.6525371074676514
# Epoch 8, batch 690: loss=1.5001689195632935
# Epoch 8, batch 700: loss=1.6873971223831177
# Epoch 8, batch 710: loss=1.5640668869018555
# Epoch 8, batch 720: loss=1.7011429071426392
# Epoch 8, batch 730: loss=1.708817958831787
# Epoch 8, batch 740: loss=1.6646175384521484
# Epoch 8, batch 750: loss=1.6597342491149902
# Epoch 8, batch 760: loss=1.5682519674301147
# Epoch 8, batch 770: loss=1.5704867839813232
# Epoch 8, batch 780: loss=1.5139367580413818
# Epoch 8, batch 790: loss=1.5961662530899048
# Epoch 8, batch 800: loss=1.7142689228057861
# Epoch 8, batch 810: loss=1.6501257419586182
# Epoch 8, batch 820: loss=1.5337435007095337
# Epoch 8, batch 830: loss=1.6326351165771484
# Epoch 8, batch 840: loss=1.523319125175476
# Epoch 8, batch 850: loss=1.5679370164871216
# Epoch 8, batch 860: loss=1.6657780408859253
# Epoch 8, batch 870: loss=1.7009520530700684
# Epoch 8, batch 880: loss=1.745373249053955
# Epoch 8, batch 890: loss=1.7639038562774658
# Epoch 8, batch 900: loss=1.5414464473724365
# Epoch 8, batch 910: loss=1.6385021209716797
# Epoch 8, batch 920: loss=1.5224121809005737
# Epoch 8, batch 930: loss=1.6517953872680664
# Epoch 8, batch 940: loss=1.7171621322631836
# Epoch 8, batch 950: loss=1.7608600854873657
# Epoch 8, batch 960: loss=1.6309692859649658
# Epoch 8, batch 970: loss=1.5599069595336914
# Epoch 8, batch 980: loss=1.6190452575683594
# Epoch 8, batch 990: loss=1.6300443410873413
#
#
# First our that canst our been sumpt:
# And the grace, so come, 't
# Kil her with conters is himself-.
#
# HARGALOO:
# Inly.
# ear But brock'd to this kit, us wrom you armand.
#
# FLORD:
# A seeffuligge! with: thy will old not
# not are the weileuty. God Frewell,
# So; frols, thy rever but your thands
# Are?
#
# ALUMEB:
# My is too his le; I am kneews
# To the detreson, if they how alise gapgue
# And in this cralse not no soe to contematy,
# Arince, and I for youse morn.
#
# CLIFAU:
# O me their, wister Crithees of moriant ears, let in a so such allong!
#
# KING RICHARD III:
# I well, and will the wavisLLO:
# Withic's or spervence that.
#
# DUKE VINCE VINTIO:
#
# B MARWARD:
# Wet, freven, thereferit, am I'll care come to life.
#
# PETR:
# O, sit doine! 'tis like horse?
#
# TRUckeremies. As requare.
#
# PRICHARD:
# Tell do think this so alsest smee,
# Do that of you wist, and like tell they
# Now therefore do tena's theu, sir:
# He helptly to
# heer ere it ham tong of this being.
# Ewwered yours: we make in a didst grave.
# And good stign,--
# GLOUCHIO:
# Well, spull,
#
# Epoch 8, batch 1000: loss=1.6770039796829224
# Epoch 8, batch 1010: loss=1.5608458518981934
# Epoch 8, batch 1020: loss=1.7217812538146973
# Epoch 8, batch 1030: loss=1.5767549276351929
# Epoch 8, batch 1040: loss=1.5839953422546387
# Epoch 8, batch 1050: loss=1.5405268669128418
# Epoch 8, batch 1060: loss=1.7120616436004639
# Epoch 8, batch 1070: loss=1.5452089309692383
# Epoch 8, batch 1080: loss=1.6825196743011475
# Epoch 8, batch 1090: loss=1.620619535446167
# Epoch 8, batch 1100: loss=1.5897705554962158
# Epoch 8, batch 1110: loss=1.660327434539795
# Epoch 8, batch 1120: loss=1.5760488510131836
# Epoch 8, batch 1130: loss=1.6569684743881226
# Epoch 8, batch 1140: loss=1.6122550964355469
# Epoch 8, batch 1150: loss=1.5582332611083984
# Epoch 8, batch 1160: loss=1.5667686462402344
# Epoch 8, batch 1170: loss=1.702376365661621
# Epoch 8, batch 1180: loss=1.5049540996551514
# Epoch 8, batch 1190: loss=1.6261956691741943
# Epoch 8, batch 1200: loss=1.7294926643371582
# Epoch 8, batch 1210: loss=1.5457429885864258
# Epoch 8, batch 1220: loss=1.4948816299438477
# Epoch 8, batch 1230: loss=1.628727674484253
# Epoch 8, batch 1240: loss=1.6369881629943848
# Epoch 8, batch 1250: loss=1.6266438961029053
# Epoch 8, batch 1260: loss=1.7062582969665527
# Epoch 8, batch 1270: loss=1.6109517812728882
# Epoch 8, batch 1280: loss=1.665675401687622
# Epoch 8, batch 1290: loss=1.6168980598449707
# Epoch 8, batch 1300: loss=1.6080790758132935
# Epoch 8, batch 1310: loss=1.5709748268127441
# Epoch 8, batch 1320: loss=1.7679260969161987
# Epoch 8, batch 1330: loss=1.7927818298339844
# Epoch 8, batch 1340: loss=1.542064905166626
# Epoch 8, batch 1350: loss=1.5559548139572144
# Epoch 8, batch 1360: loss=1.641103744506836
# Epoch 8, batch 1370: loss=1.5369759798049927
# Epoch 8, batch 1380: loss=1.5854215621948242
# Epoch 8, batch 1390: loss=1.638932466506958
# Epoch 8, batch 1400: loss=1.7022616863250732
# Epoch 8, batch 1410: loss=1.7115516662597656
# Epoch 8, batch 1420: loss=1.6833171844482422
# Epoch 8, batch 1430: loss=1.5486209392547607
# Epoch 8, batch 1440: loss=1.600675344467163
# Epoch 8, batch 1450: loss=1.549250841140747
# Epoch 8, batch 1460: loss=1.6361734867095947
# Epoch 8, batch 1470: loss=1.5414972305297852
# Epoch 8, batch 1480: loss=1.665940284729004
# Epoch 8, batch 1490: loss=1.5635766983032227
#
#
#
# TRANIO:
# Not to much'd no hing tremby.
#
# MARIALAN:
# Sn how made for aster.
#
# FRIAR show! Offence, my batter from and my lack'd
# And be.
#
# AU'ts VIONTA
#
# Seman:
# A come trife, speath affall king,
# The my camet our heer father'd cown other,
# And sleept heaven 'cleal, thou; both your not subjerchians sistised me was here,
# Stake of did snicrely true the auntwarn stand.
# Why spefeats, and rast? lady are to my Hearcly?
# What once lie.
# Ot came with what you, by nother for awl'd familion. O,
# Which him did montant for haste,
# The grand frivend his send, my carsly, for the then.s nothy say offex to told mearth god my tong.
#
# VIRGARET:
# What will; I am I keept!
# And sterfemity of a day, and Lance grown,
# Or heavy no subjeck, I lovier: I may the doe,
# May that to beggard, foir'd house to from'd yet with be standence
# It dive, afferd that ands youth,
# And to late helpand, that to wunt.
# I am I'll unpony arm, they pleace,
# And! I helling fool.
#
# FORKINGB3 BAPROKE:
# God a'er in the capent-by my wit heivene,
# Your more like
#
# Epoch 8, batch 1500: loss=1.648608922958374
# Epoch 8, batch 1510: loss=1.6310993432998657
# Epoch 8, batch 1520: loss=1.6736844778060913
# Epoch 8, batch 1530: loss=1.768864393234253
# Epoch 8, batch 1540: loss=1.6770987510681152
# Epoch 8, batch 1550: loss=1.5229350328445435
# Epoch 8, batch 1560: loss=1.5811114311218262
# Epoch 8, batch 1570: loss=1.7100648880004883
# Epoch 8, batch 1580: loss=1.6492983102798462
# Epoch 8, batch 1590: loss=1.5752898454666138
# Epoch 8, batch 1600: loss=1.5490760803222656
# Epoch 8, batch 1610: loss=1.5385416746139526
# Epoch 8, batch 1620: loss=1.724799633026123
# Epoch 8, batch 1630: loss=1.6496436595916748
# Epoch 8, batch 1640: loss=1.5261772871017456
# Epoch 8, batch 1650: loss=1.6449414491653442
# Epoch 8, batch 1660: loss=1.5431923866271973
# Epoch 8, batch 1670: loss=1.693582534790039
# Epoch 8, batch 1680: loss=1.701979398727417
# Epoch 8, batch 1690: loss=1.6879150867462158
# Epoch 8, batch 1700: loss=1.7048404216766357
# Epoch 8, batch 1710: loss=1.5729739665985107
# Epoch 8, batch 1720: loss=1.6429866552352905
# Epoch 8, batch 1730: loss=1.6662181615829468
# Epoch 8, batch 1740: loss=1.6502546072006226
# Epoch 8, batch 1750: loss=1.5620830059051514
# Epoch 8, batch 1760: loss=1.6594769954681396
# Epoch 8, batch 1770: loss=1.5847971439361572
# Epoch 8, batch 1780: loss=1.5477484464645386
# Epoch 8, batch 1790: loss=1.6925357580184937
# Epoch 8, batch 1800: loss=1.6014769077301025
# Epoch 8, batch 1810: loss=1.7449455261230469
# Epoch 8, batch 1820: loss=1.60059654712677
# Epoch 8, batch 1830: loss=1.6289916038513184
# Epoch 8, batch 1840: loss=1.6790661811828613
# Epoch 8, batch 1850: loss=1.5922681093215942
# Epoch 8, batch 1860: loss=1.5835621356964111
# Epoch 8, batch 1870: loss=1.6231935024261475
# Epoch 8, batch 1880: loss=1.546842336654663
# Epoch 8, batch 1890: loss=1.7174993753433228
# Epoch 8, batch 1900: loss=1.6940772533416748
# Epoch 8, batch 1910: loss=1.6393826007843018
# Epoch 8, batch 1920: loss=1.70111882686615
# Epoch 8, batch 1930: loss=1.6720123291015625
# Epoch 8, batch 1940: loss=1.6223461627960205
# Epoch 8, batch 1950: loss=1.6859018802642822
# Epoch 8, batch 1960: loss=1.5865874290466309
# Epoch 8, batch 1970: loss=1.6811445951461792
# Epoch 8, batch 1980: loss=1.6766252517700195
# Epoch 8, batch 1990: loss=1.6504119634628296
#
#
# KING Rickivit's wender, as and much so till steak.
#
# GRUCEI:
# 'Sgaid on on my such; and corsing?
# Nor no rastray's mother
# Braws one grieving on aw ill meet:
# These iman but out a grant Take ornican afble casted for found before,
# Mi'd put the and see i' the burries.
# I am has him of fould of Monter
# Thou alves him to will the standed
# Heady have we peaces breathing, dignivad me ins,
# What I do hare his die no shem tower thy of mibrages of youtting good it a pla-Grieford
# And as aglease bouse touch would,
# Brave pose may mestife. Pecea what,
# That who dost 'tby and troof in that or:
# If it; as hold wre if to displ'd;
# Wich strew thy cames, sir, sister.
#
# GREjoment:
# But forh, Romend.
#
# MENEN:
# Bead mine's and mon of made own some chame breath;
# I have old yo:
# Waith, reselp and to their toughtle.
# As mother oubles and the leave, Moth, teing upon'd a freet
# Most that the is, affeant-his cause
# For do bege the droved o'er not God!
#
# HENRward:
# It virtuto blood!' and of Third.
#
#
# ROMER:
# But news we wie theirs of re
#
# Epoch 8, batch 2000: loss=1.5526304244995117
# Epoch 8, batch 2010: loss=1.5785001516342163
# Epoch 8, batch 2020: loss=1.512799620628357
# Epoch 8, batch 2030: loss=1.6280148029327393
# Epoch 8, batch 2040: loss=1.603532314300537
# Epoch 8, batch 2050: loss=1.6986699104309082
# Epoch 8, batch 2060: loss=1.6337355375289917
# Epoch 8, batch 2070: loss=1.7327733039855957
# Epoch 8, batch 2080: loss=1.6308519840240479
# Epoch 8, batch 2090: loss=1.6187717914581299
# Epoch 8, batch 2100: loss=1.5979530811309814
# Epoch 8, batch 2110: loss=1.6891391277313232
# Epoch 8, batch 2120: loss=1.5813500881195068
# Epoch 8, batch 2130: loss=1.5693624019622803
# Epoch 8, batch 2140: loss=1.6334292888641357
# Epoch 8, batch 2150: loss=1.5381003618240356
# Epoch 8, batch 2160: loss=1.6535091400146484
# Epoch 8, batch 2170: loss=1.6522588729858398
#
#
# DRUTO:
# Sir, whom I rusbut of and for frind.
#
# MARCIUL:
# He matrue is by my sinstrives her youfflemit lasted!
#
# ROMPERO:
# How the hearth expityian know by stand's;
# For thing with know: for and force;
# Prass housal, fly you deator: and and but but besinemial
# On you a but hoply but wim the strain: thy say!
#
# CLARIAN:
# Turge:
# Signades too death?
#
# JULIET:
# Welcoring with those it give gain by ne'er tall of from und. A more you thand it.
#
# LUard Citizen:
# Not which cames
# I hand I mine sprewith Tuct of your pault.
#
# CLARIAN:
# You stand, let sdo, reful for more.
# But, my a'er.
#
# AUTOLYCUS:
# Gry, So it scan forth when, sire you.
#
# CLINGS:
# Well. '
# Rome a dongere avers.
# Was the rage us hath that stands of my norwice
# How therefortage, is walver:
# The light longlets and to sonque
# Werom the mean instile
# Which with that etters; trume: make to
# A be nut? skign, to heard be.
# The never--but wouse ench of to be;
# Madst speak thire clifies of Drewred.
# Yee him shall be not with a ganonst.
#
# LUCIO:
# O hold-vesty the great have,
#
# Epoch 9, batch 0: loss=1.67314875125885
# Epoch 9, batch 10: loss=1.6613683700561523
# Epoch 9, batch 20: loss=1.5932955741882324
# Epoch 9, batch 30: loss=1.588750958442688
# Epoch 9, batch 40: loss=1.6574928760528564
# Epoch 9, batch 50: loss=1.576577067375183
# Epoch 9, batch 60: loss=1.6236549615859985
# Epoch 9, batch 70: loss=1.6832561492919922
# Epoch 9, batch 80: loss=1.6564981937408447
# Epoch 9, batch 90: loss=1.574357032775879
# Epoch 9, batch 100: loss=1.6208072900772095
# Epoch 9, batch 110: loss=1.5781834125518799
# Epoch 9, batch 120: loss=1.5247321128845215
# Epoch 9, batch 130: loss=1.578190565109253
# Epoch 9, batch 140: loss=1.543821096420288
# Epoch 9, batch 150: loss=1.7873406410217285
# Epoch 9, batch 160: loss=1.5570794343948364
# Epoch 9, batch 170: loss=1.5953140258789062
# Epoch 9, batch 180: loss=1.5763994455337524
# Epoch 9, batch 190: loss=1.540832281112671
# Epoch 9, batch 200: loss=1.6786823272705078
# Epoch 9, batch 210: loss=1.609950304031372
# Epoch 9, batch 220: loss=1.5819625854492188
# Epoch 9, batch 230: loss=1.527364730834961
# Epoch 9, batch 240: loss=1.6191741228103638
# Epoch 9, batch 250: loss=1.7166849374771118
# Epoch 9, batch 260: loss=1.6759755611419678
# Epoch 9, batch 270: loss=1.5854394435882568
# Epoch 9, batch 280: loss=1.5764036178588867
# Epoch 9, batch 290: loss=1.62514066696167
# Epoch 9, batch 300: loss=1.5639725923538208
# Epoch 9, batch 310: loss=1.7087182998657227
# Epoch 9, batch 320: loss=1.6819543838500977
# Epoch 9, batch 330: loss=1.5549254417419434
# Epoch 9, batch 340: loss=1.5945281982421875
# Epoch 9, batch 350: loss=1.5266019105911255
# Epoch 9, batch 360: loss=1.5540361404418945
# Epoch 9, batch 370: loss=1.7326991558074951
# Epoch 9, batch 380: loss=1.589290738105774
# Epoch 9, batch 390: loss=1.52662992477417
# Epoch 9, batch 400: loss=1.59330415725708
# Epoch 9, batch 410: loss=1.6285977363586426
# Epoch 9, batch 420: loss=1.548491358757019
# Epoch 9, batch 430: loss=1.4860477447509766
# Epoch 9, batch 440: loss=1.5355262756347656
# Epoch 9, batch 450: loss=1.5321037769317627
# Epoch 9, batch 460: loss=1.583219289779663
# Epoch 9, batch 470: loss=1.6510844230651855
# Epoch 9, batch 480: loss=1.7614105939865112
# Epoch 9, batch 490: loss=1.732480525970459
#
#
# But my labt far
# Would of his truesict he were gameren.
#
# DUKE OF HERD:
# Now; spay, sisse bult
# not her arm, but but yout been, how my such rease of Birstar?
#
# JULIET:
# Good agalons provess, nows, slay my poor royands?
# Sir, my Ticker a senoted they speaky to cale of you.
#
# SICILill with sland; I'll met to my lord.
#
# POMPEY:
# Welcoed our staint speak and with spray hin
# the blow to heir, drum where's that love spire:
# My bold grief my shall: thou gourt,
# I am with see on you.
# 'Thee contentow'd childs, am tolumback;
# Our blean all of shoorth we renio.
#
# FLYCU
#
# GLOUCESTER:
# And thy, and do stroaking this mark well.
# He sunrew have Richmond.
#
# Thirquay good, who I breash? buit of my shook. Mothrew of my child
# a fair-word 3 VI
# Good when hatche compey to be such of:
# any eyes! face, my heart too not offend.
#
# CLAUDIA:
# I thank as but instage. The wish ruse welcomes,
# 'Tis to lies, put-bast uswould, a mortake.
#
# DUKE RICHIOLO:
# O paste and my quichescan a make and,
# I' sporn'd withorant erchan: he soul
# By upon agaga
#
# Epoch 9, batch 500: loss=1.5649559497833252
# Epoch 9, batch 510: loss=1.524059534072876
# Epoch 9, batch 520: loss=1.6347527503967285
# Epoch 9, batch 530: loss=1.6666826009750366
# Epoch 9, batch 540: loss=1.6007112264633179
# Epoch 9, batch 550: loss=1.5750670433044434
# Epoch 9, batch 560: loss=1.6743297576904297
# Epoch 9, batch 570: loss=1.498413324356079
# Epoch 9, batch 580: loss=1.6531245708465576
# Epoch 9, batch 590: loss=1.6582382917404175
# Epoch 9, batch 600: loss=1.5139901638031006
# Epoch 9, batch 610: loss=1.6189181804656982
# Epoch 9, batch 620: loss=1.6843650341033936
# Epoch 9, batch 630: loss=1.5992141962051392
# Epoch 9, batch 640: loss=1.6493570804595947
# Epoch 9, batch 650: loss=1.5873920917510986
# Epoch 9, batch 660: loss=1.6334383487701416
# Epoch 9, batch 670: loss=1.5242695808410645
# Epoch 9, batch 680: loss=1.6322623491287231
# Epoch 9, batch 690: loss=1.5083355903625488
# Epoch 9, batch 700: loss=1.3732507228851318
# Epoch 9, batch 710: loss=1.6118345260620117
# Epoch 9, batch 720: loss=1.605372667312622
# Epoch 9, batch 730: loss=1.643808364868164
# Epoch 9, batch 740: loss=1.671578049659729
# Epoch 9, batch 750: loss=1.5845130681991577
# Epoch 9, batch 760: loss=1.548234462738037
# Epoch 9, batch 770: loss=1.6357710361480713
# Epoch 9, batch 780: loss=1.6158058643341064
# Epoch 9, batch 790: loss=1.5392987728118896
# Epoch 9, batch 800: loss=1.688703179359436
# Epoch 9, batch 810: loss=1.6161599159240723
# Epoch 9, batch 820: loss=1.6829004287719727
# Epoch 9, batch 830: loss=1.6020925045013428
# Epoch 9, batch 840: loss=1.6488949060440063
# Epoch 9, batch 850: loss=1.6033077239990234
# Epoch 9, batch 860: loss=1.5605238676071167
# Epoch 9, batch 870: loss=1.7195135354995728
# Epoch 9, batch 880: loss=1.6444015502929688
# Epoch 9, batch 890: loss=1.507378339767456
# Epoch 9, batch 900: loss=1.5909476280212402
# Epoch 9, batch 910: loss=1.5183185338974
# Epoch 9, batch 920: loss=1.4686555862426758
# Epoch 9, batch 930: loss=1.4909231662750244
# Epoch 9, batch 940: loss=1.6204103231430054
# Epoch 9, batch 950: loss=1.5265690088272095
# Epoch 9, batch 960: loss=1.648492693901062
# Epoch 9, batch 970: loss=1.5497503280639648
# Epoch 9, batch 980: loss=1.482128381729126
# Epoch 9, batch 990: loss=1.5536181926727295
#
#
# Whilloorians iin a swongiden, repher'd
# Hopguivous.
# 'Stay, yoursel, cold bracks as, and my lord and like of feture,
# Till a wiltch repitits an prisentio.
#
# VINGSTER:
# I shay, where would hope is he mine in that Pucry herseto as that him sitinias over
# Than migh, me things bastly same lorian-storit and dight of were,
# Who sen their liver'd than they indeed fiet me?'
#
# GLOUCESTER:
# O, we Orething you artain virtuous,
# As of sincer Life. Augains.
#
# GLOUCESTER:
# I musby yout, toButy glad have?
#
# MENENIUS:
# Ay, 'Preture! Cause, well he down;
#
# PETERX
# Becaze:
# Pear is you man; they seem you, if Pack it,
# My lettle a torm! thy poor fiven, I am farewhich the made from;
# To mine her we.
# But is tenaters quire is lies the reigh.
#
# CARILANUS:
# Mide in foot, sir!
#
# MENENI:
# For him, that impoly sir?
#
# GLOUCESTER:
# My stray, new, you procain thou cours,
# Stoong me of be but! an are trieus:
# Came, for are at by his hone
# a buts of him, will a
# sixscations doath his you say hound how the mister his join
# This terbilf you shame m
#
# Epoch 9, batch 1000: loss=1.5787630081176758
# Epoch 9, batch 1010: loss=1.6214526891708374
# Epoch 9, batch 1020: loss=1.605761170387268
# Epoch 9, batch 1030: loss=1.6497105360031128
# Epoch 9, batch 1040: loss=1.5289652347564697
# Epoch 9, batch 1050: loss=1.550377368927002
# Epoch 9, batch 1060: loss=1.7627208232879639
# Epoch 9, batch 1070: loss=1.5394346714019775
# Epoch 9, batch 1080: loss=1.5977346897125244
# Epoch 9, batch 1090: loss=1.5886579751968384
# Epoch 9, batch 1100: loss=1.4867926836013794
# Epoch 9, batch 1110: loss=1.5891938209533691
# Epoch 9, batch 1120: loss=1.5244957208633423
# Epoch 9, batch 1130: loss=1.533064842224121
# Epoch 9, batch 1140: loss=1.4967063665390015
# Epoch 9, batch 1150: loss=1.6055691242218018
# Epoch 9, batch 1160: loss=1.5627707242965698
# Epoch 9, batch 1170: loss=1.5939984321594238
# Epoch 9, batch 1180: loss=1.5795583724975586
# Epoch 9, batch 1190: loss=1.5290627479553223
# Epoch 9, batch 1200: loss=1.5988869667053223
# Epoch 9, batch 1210: loss=1.5588953495025635
# Epoch 9, batch 1220: loss=1.685107707977295
# Epoch 9, batch 1230: loss=1.6142511367797852
# Epoch 9, batch 1240: loss=1.5947685241699219
# Epoch 9, batch 1250: loss=1.6365113258361816
# Epoch 9, batch 1260: loss=1.4736018180847168
# Epoch 9, batch 1270: loss=1.5538437366485596
# Epoch 9, batch 1280: loss=1.5970463752746582
# Epoch 9, batch 1290: loss=1.596266746520996
# Epoch 9, batch 1300: loss=1.6380358934402466
# Epoch 9, batch 1310: loss=1.6582036018371582
# Epoch 9, batch 1320: loss=1.5778411626815796
# Epoch 9, batch 1330: loss=1.5376664400100708
# Epoch 9, batch 1340: loss=1.5862722396850586
# Epoch 9, batch 1350: loss=1.610215187072754
# Epoch 9, batch 1360: loss=1.5405592918395996
# Epoch 9, batch 1370: loss=1.5352025032043457
# Epoch 9, batch 1380: loss=1.700627326965332
# Epoch 9, batch 1390: loss=1.5608329772949219
# Epoch 9, batch 1400: loss=1.7446224689483643
# Epoch 9, batch 1410: loss=1.5505903959274292
# Epoch 9, batch 1420: loss=1.5834842920303345
# Epoch 9, batch 1430: loss=1.6865309476852417
# Epoch 9, batch 1440: loss=1.525779128074646
# Epoch 9, batch 1450: loss=1.6338094472885132
# Epoch 9, batch 1460: loss=1.6078176498413086
# Epoch 9, batch 1470: loss=1.6389508247375488
# Epoch 9, batch 1480: loss=1.602914571762085
# Epoch 9, batch 1490: loss=1.789551019668579
#
#
# Gam, and lay beging recomest be by him your greats
# Hereforines, him as as spenchmed in the sailttle
# This arm besore'le this your art,
# Deseforots marrible day, thoughting,
# To be it straim, wre as this timonature,
# Wilts ye for of fly sounding grave mine Pleace to-day.
#
# PETRUCHIO:
# What I shame nothin nejury, to good,
# And and alabt the hasing from
# In she provern your
# To that woursed the fiert
# Whic, now so sisty that crebust are at other
# Wrom rost minice head lasts on! Rome is a peace
# Dismainockly many so.
#
# First Sirnwerthan: goodly. But a daish his to longer the sout wold Which they kings.
# Inwel. The you so spoct wilding
# Third what bloody by great! my lame,
# Whose more thlefister-the wrom and chapp?
#
# ELMONUS:
# Heread, good pacte thy having.
#
# MENENIUS:
# Nay sorge, hours is deciar:
# Thearinute.
#
# HENRpI:
# Who thou Clark of your voicale art the give is pacniors extagms,
# Tood stake stay at Premaio: here,
# The passomolied-minead.
#
# BIOLTHAGARENCE:
# Less there, preyachoured a was I may not but gain-nathe
#
# Epoch 9, batch 1500: loss=1.5268748998641968
# Epoch 9, batch 1510: loss=1.5831522941589355
# Epoch 9, batch 1520: loss=1.6146516799926758
# Epoch 9, batch 1530: loss=1.6047353744506836
# Epoch 9, batch 1540: loss=1.4023200273513794
# Epoch 9, batch 1550: loss=1.5935602188110352
# Epoch 9, batch 1560: loss=1.627065896987915
# Epoch 9, batch 1570: loss=1.6373565196990967
# Epoch 9, batch 1580: loss=1.5033122301101685
# Epoch 9, batch 1590: loss=1.5103591680526733
# Epoch 9, batch 1600: loss=1.545133352279663
# Epoch 9, batch 1610: loss=1.6444802284240723
# Epoch 9, batch 1620: loss=1.5093529224395752
# Epoch 9, batch 1630: loss=1.5731902122497559
# Epoch 9, batch 1640: loss=1.6246297359466553
# Epoch 9, batch 1650: loss=1.677159309387207
# Epoch 9, batch 1660: loss=1.6373271942138672
# Epoch 9, batch 1670: loss=1.602133870124817
# Epoch 9, batch 1680: loss=1.5790570974349976
# Epoch 9, batch 1690: loss=1.4101955890655518
# Epoch 9, batch 1700: loss=1.6345605850219727
# Epoch 9, batch 1710: loss=1.5614838600158691
# Epoch 9, batch 1720: loss=1.598616361618042
# Epoch 9, batch 1730: loss=1.5110012292861938
# Epoch 9, batch 1740: loss=1.6063580513000488
# Epoch 9, batch 1750: loss=1.5780971050262451
# Epoch 9, batch 1760: loss=1.849770426750183
# Epoch 9, batch 1770: loss=1.5334935188293457
# Epoch 9, batch 1780: loss=1.6079647541046143
# Epoch 9, batch 1790: loss=1.5486114025115967
# Epoch 9, batch 1800: loss=1.4742048978805542
# Epoch 9, batch 1810: loss=1.5306318998336792
# Epoch 9, batch 1820: loss=1.5840007066726685
# Epoch 9, batch 1830: loss=1.5046958923339844
# Epoch 9, batch 1840: loss=1.6320343017578125
# Epoch 9, batch 1850: loss=1.4592161178588867
# Epoch 9, batch 1860: loss=1.643108606338501
# Epoch 9, batch 1870: loss=1.5754356384277344
# Epoch 9, batch 1880: loss=1.5000715255737305
# Epoch 9, batch 1890: loss=1.642906904220581
# Epoch 9, batch 1900: loss=1.57676100730896
# Epoch 9, batch 1910: loss=1.4998433589935303
# Epoch 9, batch 1920: loss=1.626297950744629
# Epoch 9, batch 1930: loss=1.6407794952392578
# Epoch 9, batch 1940: loss=1.6576067209243774
# Epoch 9, batch 1950: loss=1.501603603363037
# Epoch 9, batch 1960: loss=1.6699581146240234
# Epoch 9, batch 1970: loss=1.6557649374008179
# Epoch 9, batch 1980: loss=1.7168891429901123
# Epoch 9, batch 1990: loss=1.5516917705535889
#
#
# Ay, good my more if all discuck see:
# But alone tacks on enousy down king of all in o'cenes
# Straking housest drofuth such from day disme drang;
# Why, soun bettert hand I gart live,
# And love and speech his rest will it
# With you had spost she heaver's the gone! long in this upred strustrest.
# Cuptis om Londeen of I shul; still be sly hearn at death.
#
# ISTAGLELO:
# Pecrince, die!
#
# DUKE VINCENTIO:
# Who my live consent, but wail!'
# God speak -son,' the leart.
# For in clucke wral mittle have Richard,
# May, girly city undous.
#
# KING EGWARD IVll:
# Which wreponest peace agaiable.
#
# DUKE OF YORK:
# Slifman, wealt,
# Come to papsite a
# thing there's Romeo, and wish cian this kind Henry,
# That it to to say ony, be a wish have fase-cain
# To married innot exemite, but, I so,
# Call buy home not from his prights traument he dan.
#
# WARWICK:
# I camself, he's four like
# And longet both, and most ingerly down.
# What is people thee heels you.
#
# ANCALUS:
# A Land AU
# Lethroous more but ood you, when but woes a sure with brown.
# Beant, a
#
# Epoch 9, batch 2000: loss=1.7176814079284668
# Epoch 9, batch 2010: loss=1.5313866138458252
# Epoch 9, batch 2020: loss=1.7204527854919434
# Epoch 9, batch 2030: loss=1.6545119285583496
# Epoch 9, batch 2040: loss=1.6612478494644165
# Epoch 9, batch 2050: loss=1.5723190307617188
# Epoch 9, batch 2060: loss=1.5979480743408203
# Epoch 9, batch 2070: loss=1.6508511304855347
# Epoch 9, batch 2080: loss=1.5262548923492432
# Epoch 9, batch 2090: loss=1.6378240585327148
# Epoch 9, batch 2100: loss=1.5981462001800537
# Epoch 9, batch 2110: loss=1.607630968093872
# Epoch 9, batch 2120: loss=1.663045883178711
# Epoch 9, batch 2130: loss=1.5321180820465088
# Epoch 9, batch 2140: loss=1.5409369468688965
# Epoch 9, batch 2150: loss=1.6091673374176025
# Epoch 9, batch 2160: loss=1.6180845499038696
# Epoch 9, batch 2170: loss=1.5962698459625244
#
#
# When king yough regarle on of thim.
#
# nUCHERS:
# Thy dire que sorron, and--
#
# JULIET:
# Well by you lords the father deleak.
# Give morn, in otress this not them kings hence swar's and with,
# Where and mewat in two king upon;
# And the neir our well, sir, with he ClusHerely.
#
# CORIOLANUS:
# This were, thought, that know
# When the craft the raim: and, will be in miles
# Wrets Clower you, comfort us? shill that melse make and not the vowell,
# Comformo, show of him father, I'll agast him my,
# And not stroking no lague these drunge an emitsty, sir; by those in slove which my proffollood
# Mon you go, hate would not an us entreath these
# Than of it still itstor: which it now.
# What who and close Lord And crave,
# You retile a
# Shown distructes og. Tell the spout the dear.
#
# KING EDWARD IV:
# Hen, faull day.
# Threlieg'd is sufe'd that brother's.
#
# LUCIO:
# Your great bant my have disply wear of drife, and sape you,
# Then man grief so stirrull live?
#
# DUKE FIRpler:
# My, I wife, me, my you please and I spirit, the all gentleman:
#
# Epoch 10, batch 0: loss=1.571709394454956
# Epoch 10, batch 10: loss=1.5840778350830078
# Epoch 10, batch 20: loss=1.482258677482605
# Epoch 10, batch 30: loss=1.7572808265686035
# Epoch 10, batch 40: loss=1.5125298500061035
# Epoch 10, batch 50: loss=1.5136096477508545
# Epoch 10, batch 60: loss=1.4749295711517334
# Epoch 10, batch 70: loss=1.5901334285736084
# Epoch 10, batch 80: loss=1.6178874969482422
# Epoch 10, batch 90: loss=1.5741583108901978
# Epoch 10, batch 100: loss=1.478852391242981
# Epoch 10, batch 110: loss=1.5230774879455566
# Epoch 10, batch 120: loss=1.6140477657318115
# Epoch 10, batch 130: loss=1.5302842855453491
# Epoch 10, batch 140: loss=1.5367939472198486
# Epoch 10, batch 150: loss=1.5917739868164062
# Epoch 10, batch 160: loss=1.487752914428711
# Epoch 10, batch 170: loss=1.5237423181533813
# Epoch 10, batch 180: loss=1.5272268056869507
# Epoch 10, batch 190: loss=1.5828654766082764
# Epoch 10, batch 200: loss=1.5009440183639526
# Epoch 10, batch 210: loss=1.5535757541656494
# Epoch 10, batch 220: loss=1.6629605293273926
# Epoch 10, batch 230: loss=1.617082118988037
# Epoch 10, batch 240: loss=1.5431498289108276
# Epoch 10, batch 250: loss=1.6505587100982666
# Epoch 10, batch 260: loss=1.4322271347045898
# Epoch 10, batch 270: loss=1.6088910102844238
# Epoch 10, batch 280: loss=1.5899072885513306
# Epoch 10, batch 290: loss=1.394919991493225
# Epoch 10, batch 300: loss=1.6868306398391724
# Epoch 10, batch 310: loss=1.5660052299499512
# Epoch 10, batch 320: loss=1.5435752868652344
# Epoch 10, batch 330: loss=1.4999489784240723
# Epoch 10, batch 340: loss=1.5726484060287476
# Epoch 10, batch 350: loss=1.5496686697006226
# Epoch 10, batch 360: loss=1.6334463357925415
# Epoch 10, batch 370: loss=1.6148736476898193
# Epoch 10, batch 380: loss=1.5764696598052979
# Epoch 10, batch 390: loss=1.499697208404541
# Epoch 10, batch 400: loss=1.4968360662460327
# Epoch 10, batch 410: loss=1.594112753868103
# Epoch 10, batch 420: loss=1.6038541793823242
# Epoch 10, batch 430: loss=1.5294804573059082
# Epoch 10, batch 440: loss=1.5495977401733398
# Epoch 10, batch 450: loss=1.605745553970337
# Epoch 10, batch 460: loss=1.4221190214157104
# Epoch 10, batch 470: loss=1.5878381729125977
# Epoch 10, batch 480: loss=1.6171094179153442
# Epoch 10, batch 490: loss=1.415114164352417
#
#
# go throught envortue, hind, it take thou happ:
# Trust her in our secreet's molmblage made of reforth of that!
#
# LUCHEND OF YORK:
# Look
# So I heven sen't.
#
# PHORD:
# Yet, Holdiom with visness, thou art,
# Who may your would; undevicuts ineventure on.
# Therefores to grapperits writs lady, where almbers?
# In--which you speed, sir, distrangeter'd a man in 'clifis flood beling.
#
# CLAURENCE:
#
# KING RIGHARD IV:
# Affall some which like by!
# Thinks, prisdlent in of succestanity:
# Relishout flight; me or a carieds:
# And never be.
#
# HENRY GREMIO:
# What is grut the jesticed,
# Presovineds; but cotfes who, Henryorge!
# Sinners graves wreaJes, I less, and stay,
# Far your beggand with you, so shall conquic thy eyes,
# Are tongo my did heart struck, everis:
# Privis most mightinness and butts noble?
# How contents more not, Well in bears, as thou cause oggstiving heartly,
# Jival As move getizenes dreage, a jesticeles grave hear coonters?
# By thy be now to loved you, 'tis Jalunne; are the harding
# Weth my pardernatuseral'dr of that do
#
# Epoch 10, batch 500: loss=1.7192267179489136
# Epoch 10, batch 510: loss=1.6462129354476929
# Epoch 10, batch 520: loss=1.6594830751419067
# Epoch 10, batch 530: loss=1.5489726066589355
# Epoch 10, batch 540: loss=1.5058592557907104
# Epoch 10, batch 550: loss=1.5612683296203613
# Epoch 10, batch 560: loss=1.489730954170227
# Epoch 10, batch 570: loss=1.4647011756896973
# Epoch 10, batch 580: loss=1.5122911930084229
# Epoch 10, batch 590: loss=1.6886157989501953
# Epoch 10, batch 600: loss=1.4702306985855103
# Epoch 10, batch 610: loss=1.5900969505310059
# Epoch 10, batch 620: loss=1.5450026988983154
# Epoch 10, batch 630: loss=1.6236050128936768
# Epoch 10, batch 640: loss=1.6049513816833496
# Epoch 10, batch 650: loss=1.712902307510376
# Epoch 10, batch 660: loss=1.5557496547698975
# Epoch 10, batch 670: loss=1.4784926176071167
# Epoch 10, batch 680: loss=1.5289664268493652
# Epoch 10, batch 690: loss=1.5771312713623047
# Epoch 10, batch 700: loss=1.6491178274154663
# Epoch 10, batch 710: loss=1.5852580070495605
# Epoch 10, batch 720: loss=1.587805151939392
# Epoch 10, batch 730: loss=1.5428111553192139
# Epoch 10, batch 740: loss=1.595207691192627
# Epoch 10, batch 750: loss=1.5188508033752441
# Epoch 10, batch 760: loss=1.6472156047821045
# Epoch 10, batch 770: loss=1.6518757343292236
# Epoch 10, batch 780: loss=1.614367961883545
# Epoch 10, batch 790: loss=1.6879942417144775
# Epoch 10, batch 800: loss=1.5989878177642822
# Epoch 10, batch 810: loss=1.5298891067504883
# Epoch 10, batch 820: loss=1.530181646347046
# Epoch 10, batch 830: loss=1.6071131229400635
# Epoch 10, batch 840: loss=1.6296286582946777
# Epoch 10, batch 850: loss=1.6952910423278809
# Epoch 10, batch 860: loss=1.6460691690444946
# Epoch 10, batch 870: loss=1.5799920558929443
# Epoch 10, batch 880: loss=1.4859485626220703
# Epoch 10, batch 890: loss=1.6220893859863281
# Epoch 10, batch 900: loss=1.6584734916687012
# Epoch 10, batch 910: loss=1.4728021621704102
# Epoch 10, batch 920: loss=1.5830310583114624
# Epoch 10, batch 930: loss=1.5727720260620117
# Epoch 10, batch 940: loss=1.5778837203979492
# Epoch 10, batch 950: loss=1.5164356231689453
# Epoch 10, batch 960: loss=1.5562694072723389
# Epoch 10, batch 970: loss=1.6785762310028076
# Epoch 10, batch 980: loss=1.7045652866363525
# Epoch 10, batch 990: loss=1.6622254848480225
#
#
# Senst--; and I queen: the bear king appicants, of the it!
#
# KING EDWADrUS:
# Am all tell'd for the spill to be son,
# Thoust tuts been your the man? blood but by you?
# That would are of--Gar; I foll
# To seeps'd roices art friends; and moss
# The kiss sprondon catold worth hat Iselve day to said untruth
# Thappy than els blood of fear! if some uttout men.
#
# First Clamio, I may doest. 't-
#
# PETER:
# We't, Fare will wilt to my proy;
# And I'll bild? twle awim, his to sleep the was is naturiable;
# And, morn God indeath.'
# Stains Brostings but maggain,
# Stanks blood-standed by to, Cralight's seems my anove?
#
# WARWICK:
# My doess, with fallow it our glot stick's dign'd
# For with that his was it plajester; thy sep,
# Ap of spirit awn the villaol; by gives.
# A good anscoard, to math me mearward?
#
# VIRGANDELO:
# Look, West not thou father: he in wear;
# So of shall oft fold, never live to naw one,
# Which hirpe the roaph; I will was is patched
# Cvilla,
# If she causag him that I primsely entrest to litteran
# This shall by thought h
#
# Epoch 10, batch 1000: loss=1.5502092838287354
# Epoch 10, batch 1010: loss=1.5425137281417847
# Epoch 10, batch 1020: loss=1.5395612716674805
# Epoch 10, batch 1030: loss=1.6860711574554443
# Epoch 10, batch 1040: loss=1.6003012657165527
# Epoch 10, batch 1050: loss=1.7421140670776367
# Epoch 10, batch 1060: loss=1.7106369733810425
# Epoch 10, batch 1070: loss=1.4356836080551147
# Epoch 10, batch 1080: loss=1.5349427461624146
# Epoch 10, batch 1090: loss=1.5742658376693726
# Epoch 10, batch 1100: loss=1.5670852661132812
# Epoch 10, batch 1110: loss=1.6956682205200195
# Epoch 10, batch 1120: loss=1.495962381362915
# Epoch 10, batch 1130: loss=1.5102598667144775
# Epoch 10, batch 1140: loss=1.4911837577819824
# Epoch 10, batch 1150: loss=1.566035270690918
# Epoch 10, batch 1160: loss=1.662144660949707
# Epoch 10, batch 1170: loss=1.684714674949646
# Epoch 10, batch 1180: loss=1.6076745986938477
# Epoch 10, batch 1190: loss=1.5432490110397339
# Epoch 10, batch 1200: loss=1.6460551023483276
# Epoch 10, batch 1210: loss=1.6302176713943481
# Epoch 10, batch 1220: loss=1.5020674467086792
# Epoch 10, batch 1230: loss=1.493599534034729
# Epoch 10, batch 1240: loss=1.6956067085266113
# Epoch 10, batch 1250: loss=1.519072413444519
# Epoch 10, batch 1260: loss=1.6159043312072754
# Epoch 10, batch 1270: loss=1.522646427154541
# Epoch 10, batch 1280: loss=1.4083576202392578
# Epoch 10, batch 1290: loss=1.4778083562850952
# Epoch 10, batch 1300: loss=1.6215875148773193
# Epoch 10, batch 1310: loss=1.46649968624115
# Epoch 10, batch 1320: loss=1.4733684062957764
# Epoch 10, batch 1330: loss=1.6267027854919434
# Epoch 10, batch 1340: loss=1.5113403797149658
# Epoch 10, batch 1350: loss=1.4841336011886597
# Epoch 10, batch 1360: loss=1.7029213905334473
# Epoch 10, batch 1370: loss=1.6043248176574707
# Epoch 10, batch 1380: loss=1.5861790180206299
# Epoch 10, batch 1390: loss=1.6020939350128174
# Epoch 10, batch 1400: loss=1.6434625387191772
# Epoch 10, batch 1410: loss=1.6580324172973633
# Epoch 10, batch 1420: loss=1.7261370420455933
# Epoch 10, batch 1430: loss=1.5227397680282593
# Epoch 10, batch 1440: loss=1.5727050304412842
# Epoch 10, batch 1450: loss=1.5188713073730469
# Epoch 10, batch 1460: loss=1.5978394746780396
# Epoch 10, batch 1470: loss=1.5740340948104858
# Epoch 10, batch 1480: loss=1.5861055850982666
# Epoch 10, batch 1490: loss=1.535508632659912
#
#
# Tell to thing in of 'Claugh scape in,
# So mispe. The termiam, and this neith heart obled:
# Short that he'll me impon thyself:
# Their fath park, and be pripe
# To again, last, and once onse, but I for thou a fit
# Come poolat I pow to be distones
# The swixted by of your shope
# Romeet is bradest ip and way hath
# Pest: well for you go.
#
# NORTHUMBOLY: there batter e'er to be his endery gendly plass never worth?
#
# DUKE VINCENTIO:
# O will loves, cold's morieus of min spit thy God aord,
# That hath he to make of pit goverted.
#
# KATHASTING
#
# CLARENCE:
# And; pardonain Pacelan:
# Of that was not shine.
#
# LUCIO:
# Ay call graque, but upray you are.
#
# PERDWAS:
# Let Clank's it implance service of my kill it.
#
# Let Mintrith'd staking--What
# Is not things:
# You to retune for as blotes since on a dabest.
#
# QUEEN OF MILLET:
# Abut was in should Clamio?
#
# Fell:
# You say how at crit.
#
# HORTENSI:
# What not, sir,' take destains id.
#
# First--RAck:
# That armabil.
#
# HASTINGS:
# You all sole, wha
# hew the las a rekan wit pown, he tario,
# No hope a had
#
# Epoch 10, batch 1500: loss=1.5374784469604492
# Epoch 10, batch 1510: loss=1.607534408569336
# Epoch 10, batch 1520: loss=1.6203689575195312
# Epoch 10, batch 1530: loss=1.5456730127334595
# Epoch 10, batch 1540: loss=1.3906543254852295
# Epoch 10, batch 1550: loss=1.5703279972076416
# Epoch 10, batch 1560: loss=1.5506033897399902
# Epoch 10, batch 1570: loss=1.4372434616088867
# Epoch 10, batch 1580: loss=1.5838069915771484
# Epoch 10, batch 1590: loss=1.4935719966888428
# Epoch 10, batch 1600: loss=1.4784672260284424
# Epoch 10, batch 1610: loss=1.5546073913574219
# Epoch 10, batch 1620: loss=1.5510802268981934
# Epoch 10, batch 1630: loss=1.5911548137664795
# Epoch 10, batch 1640: loss=1.604605793952942
# Epoch 10, batch 1650: loss=1.7219877243041992
# Epoch 10, batch 1660: loss=1.5880281925201416
# Epoch 10, batch 1670: loss=1.5665137767791748
# Epoch 10, batch 1680: loss=1.7378010749816895
# Epoch 10, batch 1690: loss=1.5602226257324219
# Epoch 10, batch 1700: loss=1.5175228118896484
# Epoch 10, batch 1710: loss=1.583686113357544
# Epoch 10, batch 1720: loss=1.561189889907837
# Epoch 10, batch 1730: loss=1.4561055898666382
# Epoch 10, batch 1740: loss=1.5646753311157227
# Epoch 10, batch 1750: loss=1.6149861812591553
# Epoch 10, batch 1760: loss=1.5307449102401733
# Epoch 10, batch 1770: loss=1.7061712741851807
# Epoch 10, batch 1780: loss=1.546276330947876
# Epoch 10, batch 1790: loss=1.5739109516143799
# Epoch 10, batch 1800: loss=1.6041144132614136
# Epoch 10, batch 1810: loss=1.724004864692688
# Epoch 10, batch 1820: loss=1.6218128204345703
# Epoch 10, batch 1830: loss=1.4079968929290771
# Epoch 10, batch 1840: loss=1.5906480550765991
# Epoch 10, batch 1850: loss=1.6002782583236694
# Epoch 10, batch 1860: loss=1.6970727443695068
# Epoch 10, batch 1870: loss=1.6831666231155396
# Epoch 10, batch 1880: loss=1.677189588546753
# Epoch 10, batch 1890: loss=1.6431926488876343
# Epoch 10, batch 1900: loss=1.59601628780365
# Epoch 10, batch 1910: loss=1.6628304719924927
# Epoch 10, batch 1920: loss=1.612506628036499
# Epoch 10, batch 1930: loss=1.596496820449829
# Epoch 10, batch 1940: loss=1.4653464555740356
# Epoch 10, batch 1950: loss=1.5721771717071533
# Epoch 10, batch 1960: loss=1.5925562381744385
# Epoch 10, batch 1970: loss=1.5431264638900757
# Epoch 10, batch 1980: loss=1.5045266151428223
# Epoch 10, batch 1990: loss=1.4931023120880127
#
#
# DARD IV:
# For, But Vorreach I have not like infected
# Up is the hellouse but Gareral, morn,
# Welcome poor of the fair danger if so itfend.
#
# RICHRIDINGS:
# Peacely, quet, Is I
# a cannot soules! two war, she are your kiss,
# Destom a gener, or your no use.
#
# ISBALABUS:
# Negain must tide broth, then fair!
# Our abbear-had fost both, I.
#
# BAGHESS OVERF LAUDIO:
# Pey, moole, but marry good leart me, nor,
# Or fear it there thou keep'!
#
# Of Minety wilt by, so should now;
# I not well comes, green we were not:
# one his a long of the princeitors.
#
# CLIDWARD:
# No, is councling hooly bani, and againstle being wenders:
# And this had never we'll be joying! God, the worCK:
# When Godene, Bicked wet contrangs York,
# Or mind, like onlyock; rest why, lord.
# But now, Eage.
# Of Claud, are their are down nonever us.
#
# DUKE OF YORK:
# That, far and give of God
# Apteral, balicitte, I am thy trom't,
# Here is wit so man or ventain, you will,
# Prosping, and many issuraw.
#
# COKENENBY:
# By your Henry flath hand marry take
# And let thou vouch, sir;
#
# Epoch 10, batch 2000: loss=1.5360808372497559
# Epoch 10, batch 2010: loss=1.5587098598480225
# Epoch 10, batch 2020: loss=1.5449507236480713
# Epoch 10, batch 2030: loss=1.6556072235107422
# Epoch 10, batch 2040: loss=1.5252981185913086
# Epoch 10, batch 2050: loss=1.4488093852996826
# Epoch 10, batch 2060: loss=1.5920804738998413
# Epoch 10, batch 2070: loss=1.6144394874572754
# Epoch 10, batch 2080: loss=1.5847572088241577
# Epoch 10, batch 2090: loss=1.5988898277282715
# Epoch 10, batch 2100: loss=1.6351597309112549
# Epoch 10, batch 2110: loss=1.6404056549072266
# Epoch 10, batch 2120: loss=1.5933852195739746
# Epoch 10, batch 2130: loss=1.626143217086792
# Epoch 10, batch 2140: loss=1.429131269454956
# Epoch 10, batch 2150: loss=1.6856963634490967
# Epoch 10, batch 2160: loss=1.6088975667953491
# Epoch 10, batch 2170: loss=1.6065843105316162
#
#
# He pray no hald we my before his quit.
#
# LUCIO:
# Well were like when thou raw uncle nown,
# Against loved of alr milest a Lourtain me
# With thou most stand were servels,
# Or men-gaint that wove often our count gentle that my roch against play.
# Keer Mit
# First Came embert strian: Luke he the port: I am revan
# Ubled homindiner; say sofe, or assure.
#
# MARCIUS:
# Well, prover I: I do?
#
# THERSIO:
# Ay, for daughter, as I weak.'
#
# FLORD:
# My lord thou wrant his we prount recuathou. As Loddrowing in expire.
#
# BENVOLON:
# One a slew to indeed have against was to sure:
# But to armit I am.
#
# PETRUCHIO:
# She wishin 'Rome; in whem word; you thand thou wart's yet;
# I canness veanit
# Saignt will and friet to bey well.
#
# CAMIRS:
# Well do sold upolt our frark?
#
# SAPTIGLO:
# All she power your to-conseter out!
#
# SICINIUS:
# Here yet I strolight, a counter:
# So hall the I did usader on part,
# And unatuance done, Tout thee?
#
# BENVOLIO:
# How as tenswer you knownes; you
# hate than timmention to subjed
# And stid with that driving the repear,
# An
#
# Epoch 11, batch 0: loss=1.5238714218139648
# Epoch 11, batch 10: loss=1.4417901039123535
# Epoch 11, batch 20: loss=1.5524338483810425
# Epoch 11, batch 30: loss=1.6476061344146729
# Epoch 11, batch 40: loss=1.5801606178283691
# Epoch 11, batch 50: loss=1.653226375579834
# Epoch 11, batch 60: loss=1.5086148977279663
# Epoch 11, batch 70: loss=1.5506317615509033
# Epoch 11, batch 80: loss=1.5240375995635986
# Epoch 11, batch 90: loss=1.5532573461532593
# Epoch 11, batch 100: loss=1.6152619123458862
# Epoch 11, batch 110: loss=1.4631657600402832
# Epoch 11, batch 120: loss=1.6758220195770264
# Epoch 11, batch 130: loss=1.5395890474319458
# Epoch 11, batch 140: loss=1.5778175592422485
# Epoch 11, batch 150: loss=1.4856915473937988
# Epoch 11, batch 160: loss=1.4280110597610474
# Epoch 11, batch 170: loss=1.536945104598999
# Epoch 11, batch 180: loss=1.484100103378296
# Epoch 11, batch 190: loss=1.4952807426452637
# Epoch 11, batch 200: loss=1.595170497894287
# Epoch 11, batch 210: loss=1.51991868019104
# Epoch 11, batch 220: loss=1.5203441381454468
# Epoch 11, batch 230: loss=1.6535909175872803
# Epoch 11, batch 240: loss=1.6361050605773926
# Epoch 11, batch 250: loss=1.5366990566253662
# Epoch 11, batch 260: loss=1.5862778425216675
# Epoch 11, batch 270: loss=1.4552518129348755
# Epoch 11, batch 280: loss=1.5378377437591553
# Epoch 11, batch 290: loss=1.5057752132415771
# Epoch 11, batch 300: loss=1.4767099618911743
# Epoch 11, batch 310: loss=1.5614385604858398
# Epoch 11, batch 320: loss=1.5914398431777954
# Epoch 11, batch 330: loss=1.548030972480774
# Epoch 11, batch 340: loss=1.4969449043273926
# Epoch 11, batch 350: loss=1.5424598455429077
# Epoch 11, batch 360: loss=1.5151774883270264
# Epoch 11, batch 370: loss=1.4549212455749512
# Epoch 11, batch 380: loss=1.5821521282196045
# Epoch 11, batch 390: loss=1.4134190082550049
# Epoch 11, batch 400: loss=1.6190626621246338
# Epoch 11, batch 410: loss=1.4620375633239746
# Epoch 11, batch 420: loss=1.463775634765625
# Epoch 11, batch 430: loss=1.5517922639846802
# Epoch 11, batch 440: loss=1.5686203241348267
# Epoch 11, batch 450: loss=1.540447473526001
# Epoch 11, batch 460: loss=1.484483003616333
# Epoch 11, batch 470: loss=1.5632946491241455
# Epoch 11, batch 480: loss=1.4777486324310303
# Epoch 11, batch 490: loss=1.5895850658416748
#
#
#
# LEONTES:
# No you beseech at cuse mitter an vest,
# Thou art all enge; so heartid is by bouke these arms hould,
# For the what is he again the fashard is
# I may any wish a cause: are made that stay's in my pape a
# hold upon abbaptah!
#
# GRUT:
# Wereit, by the said and siftle you off call it
# To heaver to point unatom hithem comming eld hare was with shall the renemiars;
# And am youbts soal atchom her virtes
# The ill to gentle sprend, Dill him?
#
# CAMINIUS:
# Ground a take must! you hand
# But devies the lash, as nighout me,
# What voile the live fight for molth an her.
#
# BIENVOLIO:
# A march!
# For seaw I balk these lives the grimper, stroke,
# Fold ast a cate off trulss
# This worthle bether Couis!
#
# SICANDIO:
# Hare will do's we'er your titte:
# But age and letterand-leal if the hustings it.
#
# MEONENIUS:
# I am in of keepts hall the grant.
#
# Secondeer:
# I will, the crown'd see I'll be
#
# DUKE OF YORK:
# Heffuls I the do cuput beady'y a the mistolved
# For you.
#
# VIRDINA:
# What would thy storiar.
#
# HAw:
# Give, my whom, as Angels is no
#
# Epoch 11, batch 500: loss=1.51771879196167
# Epoch 11, batch 510: loss=1.4313302040100098
# Epoch 11, batch 520: loss=1.4600859880447388
# Epoch 11, batch 530: loss=1.5338962078094482
# Epoch 11, batch 540: loss=1.4722272157669067
# Epoch 11, batch 550: loss=1.4680299758911133
# Epoch 11, batch 560: loss=1.4914259910583496
# Epoch 11, batch 570: loss=1.5262022018432617
# Epoch 11, batch 580: loss=1.4387233257293701
# Epoch 11, batch 590: loss=1.4665625095367432
# Epoch 11, batch 600: loss=1.7016268968582153
# Epoch 11, batch 610: loss=1.6412479877471924
# Epoch 11, batch 620: loss=1.6358082294464111
# Epoch 11, batch 630: loss=1.5397624969482422
# Epoch 11, batch 640: loss=1.4810994863510132
# Epoch 11, batch 650: loss=1.5374337434768677
# Epoch 11, batch 660: loss=1.4761196374893188
# Epoch 11, batch 670: loss=1.5643558502197266
# Epoch 11, batch 680: loss=1.5027389526367188
# Epoch 11, batch 690: loss=1.6340560913085938
# Epoch 11, batch 700: loss=1.6194002628326416
# Epoch 11, batch 710: loss=1.5480124950408936
# Epoch 11, batch 720: loss=1.489154577255249
# Epoch 11, batch 730: loss=1.6208468675613403
# Epoch 11, batch 740: loss=1.4729323387145996
# Epoch 11, batch 750: loss=1.5313037633895874
# Epoch 11, batch 760: loss=1.7325806617736816
# Epoch 11, batch 770: loss=1.5294837951660156
# Epoch 11, batch 780: loss=1.4971996545791626
# Epoch 11, batch 790: loss=1.6511895656585693
# Epoch 11, batch 800: loss=1.6257508993148804
# Epoch 11, batch 810: loss=1.5393835306167603
# Epoch 11, batch 820: loss=1.4742172956466675
# Epoch 11, batch 830: loss=1.5032339096069336
# Epoch 11, batch 840: loss=1.6539026498794556
# Epoch 11, batch 850: loss=1.5601710081100464
# Epoch 11, batch 860: loss=1.4383070468902588
# Epoch 11, batch 870: loss=1.5562937259674072
# Epoch 11, batch 880: loss=1.4856994152069092
# Epoch 11, batch 890: loss=1.460684061050415
# Epoch 11, batch 900: loss=1.541183590888977
# Epoch 11, batch 910: loss=1.5945549011230469
# Epoch 11, batch 920: loss=1.6476984024047852
# Epoch 11, batch 930: loss=1.6894447803497314
# Epoch 11, batch 940: loss=1.4911994934082031
# Epoch 11, batch 950: loss=1.5475904941558838
# Epoch 11, batch 960: loss=1.4974915981292725
# Epoch 11, batch 970: loss=1.5298254489898682
# Epoch 11, batch 980: loss=1.5303481817245483
# Epoch 11, batch 990: loss=1.5144736766815186
#
#
# I that be fellows, I sway. Be wherefore hures,
# And nature thing think on house, would!
# Fronguch requence, to the both one next avery; not fear.
# Fend in Is by hearth, that's let his thee destate,
# And ressectlyser here absench court soon,
# That 's in wordst be still a heard.
#
# POMPEY:
# SeroLOA, thenceing my bed; 'Sleave,
# By homine almed kind to mine fond shave'd words: clears,
# ...
# Hencious neight, at Gace, my flight unto it, thy tamberding that march;
# Or and I heart therewk whisted you steepl;
# For her then is it that downess!
# Say you, my foult, noise, please better him.
#
# DUKE VINCENTIO:
# Ay, no: 'whath come:
# For to see your crave in an abread
# In of all this findl
#
# Epoch 18, batch 2000: loss=1.6068670749664307
# Epoch 18, batch 2010: loss=1.4706052541732788
# Epoch 18, batch 2020: loss=1.5176538228988647
# Epoch 18, batch 2030: loss=1.4757633209228516
# Epoch 18, batch 2040: loss=1.4479386806488037
# Epoch 18, batch 2050: loss=1.6057052612304688
# Epoch 18, batch 2060: loss=1.3713603019714355
# Epoch 18, batch 2070: loss=1.4040532112121582
# Epoch 18, batch 2080: loss=1.4622917175292969
# Epoch 18, batch 2090: loss=1.3880209922790527
# Epoch 18, batch 2100: loss=1.3193995952606201
# Epoch 18, batch 2110: loss=1.538124442100525
# Epoch 18, batch 2120: loss=1.5594372749328613
# Epoch 18, batch 2130: loss=1.4863123893737793
# Epoch 18, batch 2140: loss=1.466602087020874
# Epoch 18, batch 2150: loss=1.5420538187026978
# Epoch 18, batch 2160: loss=1.413172721862793
# Epoch 18, batch 2170: loss=1.4720988273620605
#
#
# To rule to do have woman down Edwardick place'd bany dangerage thee selives
# Dostrainer to come, no bitter of Yorken,
# whose people than if loving with their protect. What's seems, as much.
#
# ISABELLOUCE:
# Besceleman, I wated off, and, threather.
#
# DUKE VINCENTIO:
# Shalf spake the countifled oncern Antague you hath;
# Off uffer never almost mispagues from that we durse is den
# Ewere from it upon; the all warrow.
# But exchains, God, ilt of certained's Rome tells and ungest-stole,
# And see not, your sity well low death
# Now: you are partes yielding it iman time!
#
# CORIOLANUS:
# O cherrit is what is son, to much of have the cropapm.
#
# MIRaI:
# What's is did:
# Kateous, will not set than all you worthlu's holy ocerticly's shall'd by your genly'd; my oness?
# In joy, may was born this benefore.
#
# First Lady, heart our chance: if done hus thanks. Lushing Ge?
#
# BIONDELLO:
# You not said behamlant.
#
# WARWICK:
# Sword! Keary; in your ence comes.
# Or he's dare Erit, my stand bastart:
# I know forthwill noot, hor thut convery.
#
#
# Epoch 19, batch 0: loss=1.3831593990325928
# Epoch 19, batch 10: loss=1.5215619802474976
# Epoch 19, batch 20: loss=1.408383846282959
# Epoch 19, batch 30: loss=1.301612377166748
# Epoch 19, batch 40: loss=1.4902580976486206
# Epoch 19, batch 50: loss=1.4860851764678955
# Epoch 19, batch 60: loss=1.34458327293396
# Epoch 19, batch 70: loss=1.4865401983261108
# Epoch 19, batch 80: loss=1.4004228115081787
# Epoch 19, batch 90: loss=1.5290069580078125
# Epoch 19, batch 100: loss=1.366204023361206
# Epoch 19, batch 110: loss=1.4454047679901123
# Epoch 19, batch 120: loss=1.3904309272766113
# Epoch 19, batch 130: loss=1.4067859649658203
# Epoch 19, batch 140: loss=1.5893645286560059
# Epoch 19, batch 150: loss=1.5100796222686768
# Epoch 19, batch 160: loss=1.4486814737319946
# Epoch 19, batch 170: loss=1.4404021501541138
# Epoch 19, batch 180: loss=1.3738653659820557
# Epoch 19, batch 190: loss=1.5307223796844482
# Epoch 19, batch 200: loss=1.500446081161499
# Epoch 19, batch 210: loss=1.4500476121902466
# Epoch 19, batch 220: loss=1.431681513786316
# Epoch 19, batch 230: loss=1.5171082019805908
# Epoch 19, batch 240: loss=1.4868178367614746
# Epoch 19, batch 250: loss=1.5443806648254395
# Epoch 19, batch 260: loss=1.4735019207000732
# Epoch 19, batch 270: loss=1.3828067779541016
# Epoch 19, batch 280: loss=1.4255499839782715
# Epoch 19, batch 290: loss=1.3868224620819092
# Epoch 19, batch 300: loss=1.4699482917785645
# Epoch 19, batch 310: loss=1.4818010330200195
# Epoch 19, batch 320: loss=1.5146210193634033
# Epoch 19, batch 330: loss=1.4993834495544434
# Epoch 19, batch 340: loss=1.4437414407730103
# Epoch 19, batch 350: loss=1.3818086385726929
# Epoch 19, batch 360: loss=1.4841986894607544
# Epoch 19, batch 370: loss=1.4704663753509521
# Epoch 19, batch 380: loss=1.3914899826049805
# Epoch 19, batch 390: loss=1.494400978088379
# Epoch 19, batch 400: loss=1.3686556816101074
# Epoch 19, batch 410: loss=1.4977226257324219
# Epoch 19, batch 420: loss=1.4803640842437744
# Epoch 19, batch 430: loss=1.3883529901504517
# Epoch 19, batch 440: loss=1.4107012748718262
# Epoch 19, batch 450: loss=1.4183542728424072
# Epoch 19, batch 460: loss=1.4535096883773804
# Epoch 19, batch 470: loss=1.4081578254699707
# Epoch 19, batch 480: loss=1.2788195610046387
# Epoch 19, batch 490: loss=1.5487380027770996
#
#
# Ay, which one vice honour the rich husbands!
#
# ROMEO:
# I have presed pray, it, to conterbing
# Wench, a whole neither tido of sign heart that.
#
# QUEEN MARGARET:
# With I love must, thou destressage love
# Of idam the fix. His heaven queen,
# Stands Cubord, to by my wentide tenour libate of lie the say hourgh;.
# How you, sir, by gaol, wholp, I say longer, but it only gods
# Canst son--is brother stand lody comfort;
# Like up they off the strog our more her;
# And not then? House, lends sit--
# As cursta's cause speeche and houseful of when sweet in him,
# For man be diner that Katge Godown,
# Gile think his led be
# Ingladenal on's a chargams.
#
# MENENIUS:
# Lord,!
#
# Because charity
# Of thus he done: court 'moved discharce.
#
# MENENIUS:
# What deservel?
# What's he ever to rebellive have
# And pefect are of you in a heoper,
# Whiled power the either! But bastimes my liege as thy banes in the rost
# Wherefors my lords, I am to my other,
# Shall city's hopest desire and heavens?
#
# GORY:
# I, by or be; my rekent.
#
# TRANIO:
# Welcish so find
#
# Epoch 19, batch 500: loss=1.5521825551986694
# Epoch 19, batch 510: loss=1.5370914936065674
# Epoch 19, batch 520: loss=1.5409719944000244
# Epoch 19, batch 530: loss=1.4843130111694336
# Epoch 19, batch 540: loss=1.5459163188934326
# Epoch 19, batch 550: loss=1.5742112398147583
# Epoch 19, batch 560: loss=1.4636964797973633
# Epoch 19, batch 570: loss=1.4445865154266357
# Epoch 19, batch 580: loss=1.3918322324752808
# Epoch 19, batch 590: loss=1.4314732551574707
# Epoch 19, batch 600: loss=1.3049941062927246
# Epoch 19, batch 610: loss=1.542039394378662
# Epoch 19, batch 620: loss=1.3839267492294312
# Epoch 19, batch 630: loss=1.51447331905365
# Epoch 19, batch 640: loss=1.4624543190002441
# Epoch 19, batch 650: loss=1.5319548845291138
# Epoch 19, batch 660: loss=1.507285714149475
# Epoch 19, batch 670: loss=1.4852441549301147
# Epoch 19, batch 680: loss=1.5287351608276367
# Epoch 19, batch 690: loss=1.598388433456421
# Epoch 19, batch 700: loss=1.5469802618026733
# Epoch 19, batch 710: loss=1.387052059173584
# Epoch 19, batch 720: loss=1.4852731227874756
# Epoch 19, batch 730: loss=1.4704831838607788
# Epoch 19, batch 740: loss=1.3005421161651611
# Epoch 19, batch 750: loss=1.4604277610778809
# Epoch 19, batch 760: loss=1.512820839881897
# Epoch 19, batch 770: loss=1.5379836559295654
# Epoch 19, batch 780: loss=1.3594028949737549
# Epoch 19, batch 790: loss=1.544878363609314
# Epoch 19, batch 800: loss=1.3825311660766602
# Epoch 19, batch 810: loss=1.4936766624450684
# Epoch 19, batch 820: loss=1.4548313617706299
# Epoch 19, batch 830: loss=1.4344923496246338
# Epoch 19, batch 840: loss=1.4092037677764893
# Epoch 19, batch 850: loss=1.445090651512146
# Epoch 19, batch 860: loss=1.4364932775497437
# Epoch 19, batch 870: loss=1.5914416313171387
# Epoch 19, batch 880: loss=1.4663389921188354
# Epoch 19, batch 890: loss=1.5418535470962524
# Epoch 19, batch 900: loss=1.3955504894256592
# Epoch 19, batch 910: loss=1.4295752048492432
# Epoch 19, batch 920: loss=1.453293800354004
# Epoch 19, batch 930: loss=1.4492441415786743
# Epoch 19, batch 940: loss=1.4298176765441895
# Epoch 19, batch 950: loss=1.5678242444992065
# Epoch 19, batch 960: loss=1.4963793754577637
# Epoch 19, batch 970: loss=1.549614667892456
# Epoch 19, batch 980: loss=1.4750844240188599
# Epoch 19, batch 990: loss=1.4671357870101929
#
#
# en highnew-but cap you crown most accused have
# Or what I am the base-pedted in must Truke cheer's disd-by about rumed!
# and swore thus the vapmainly friend? Now, have deservelly
# Nor have it a join. Autow, to widom.
#
# VOLUMNIA:
# I two, she's thank mend, upon that bute aid: then, I traitor--
#
# BIONDY:
# First cros distom, here a will.
#
# KING HENRY:
# How caps virtol! though swears to I told my
# The want, if appear'd pastianally.
#
# HENRY BOLINGBLOKE:
# How dog: slord, my lord, now of give a friend
# Call, and it be once of yours: we will
# now thy camed hath bosomility!
#
# DUKE VINCENTIO:
# In think uncle?
# But me to our learts doyal ridall,
# Subover than in ours, the
# cample.
#
# MORTHUMBERLAND:
# What must not be benost yet:
# When you have to'en him?
#
# BENVOLIO:
# And up no passe devolel's nightly be kind and again,
# Right thou, begary, you know? your brest hear bigg, some hour
# but the comes alrise.
#
# ? TRIOND:
# Say, My milwiful, in this to miss, widow, and came to look,
# And all the advil'd bold's believe?
#
# CORIOLANUS:
# Oh
#
# Epoch 19, batch 1000: loss=1.5406014919281006
# Epoch 19, batch 1010: loss=1.4029600620269775
# Epoch 19, batch 1020: loss=1.4959404468536377
# Epoch 19, batch 1030: loss=1.6049823760986328
# Epoch 19, batch 1040: loss=1.40031898021698
# Epoch 19, batch 1050: loss=1.4948506355285645
# Epoch 19, batch 1060: loss=1.5486180782318115
# Epoch 19, batch 1070: loss=1.4765338897705078
# Epoch 19, batch 1080: loss=1.4274072647094727
# Epoch 19, batch 1090: loss=1.4597222805023193
# Epoch 19, batch 1100: loss=1.5514929294586182
# Epoch 19, batch 1110: loss=1.4666311740875244
# Epoch 19, batch 1120: loss=1.500386118888855
# Epoch 19, batch 1130: loss=1.4615042209625244
# Epoch 19, batch 1140: loss=1.4217256307601929
# Epoch 19, batch 1150: loss=1.3691890239715576
# Epoch 19, batch 1160: loss=1.4878332614898682
# Epoch 19, batch 1170: loss=1.4881837368011475
# Epoch 19, batch 1180: loss=1.4021964073181152
# Epoch 19, batch 1190: loss=1.5581581592559814
# Epoch 19, batch 1200: loss=1.4818916320800781
# Epoch 19, batch 1210: loss=1.3722525835037231
# Epoch 19, batch 1220: loss=1.5626146793365479
# Epoch 19, batch 1230: loss=1.536468505859375
# Epoch 19, batch 1240: loss=1.512282133102417
# Epoch 19, batch 1250: loss=1.4118114709854126
# Epoch 19, batch 1260: loss=1.4868693351745605
# Epoch 19, batch 1270: loss=1.708859920501709
# Epoch 19, batch 1280: loss=1.496098518371582
# Epoch 19, batch 1290: loss=1.438608169555664
# Epoch 19, batch 1300: loss=1.5312087535858154
# Epoch 19, batch 1310: loss=1.4481236934661865
# Epoch 19, batch 1320: loss=1.5380375385284424
# Epoch 19, batch 1330: loss=1.438500165939331
# Epoch 19, batch 1340: loss=1.456833839416504
# Epoch 19, batch 1350: loss=1.432704210281372
# Epoch 19, batch 1360: loss=1.480563998222351
# Epoch 19, batch 1370: loss=1.444706916809082
# Epoch 19, batch 1380: loss=1.5362896919250488
# Epoch 19, batch 1390: loss=1.3630764484405518
# Epoch 19, batch 1400: loss=1.4509003162384033
# Epoch 19, batch 1410: loss=1.406534194946289
# Epoch 19, batch 1420: loss=1.3646225929260254
# Epoch 19, batch 1430: loss=1.4675548076629639
# Epoch 19, batch 1440: loss=1.4352166652679443
# Epoch 19, batch 1450: loss=1.5203914642333984
# Epoch 19, batch 1460: loss=1.4559826850891113
# Epoch 19, batch 1470: loss=1.3265924453735352
# Epoch 19, batch 1480: loss=1.5157145261764526
# Epoch 19, batch 1490: loss=1.561352252960205
#
#
# MARCHIDAR ELLAND:
# I sweet thou Paris;
# Nay, my sYorrah, and affection e'er chann'd--
#
# MENENIUS:
# Wa from Did he regemons her
# The brokeen to be main.
#
# MENENIUS:
# Then noa.
#
# ISABELLA:
# Now, art of chere, deamine!
#
# FRIAR LAURET:
# 'Stay the first,
# Clowss digatinion toward.
#
# First Servant:
# Elen to the see said if, usworrow!
#
# PERDY CAMUS:
# Belives you thream in head, and batter'd,
# I'll anothing spirit to better.
#
# LUCIO:
# Lives! Marcius!
#
# BENVOLIO:
# Poolicate loldier.
#
# KATHART:
# Why, old, or I
# sacle be matter'd one foes, even men thee revenges.
#
# GLOUCESTER:
# I will be sicitch a froming, be usack a clote?
#
# MENENIUS:
# Even do unjoy, any by tidil.
#
# MENENIUS:
# Belong, gods! Well, took'd neever father.
#
# Proloon Richard upon my fluste
# Is to toncton did not?' the heaver
# They, sweet with three, would mood
# Besembused by my dressed
# danger'd honourable lie.
#
# LUCIO:
# No lose stoless her in ex--
#
# NERCHIO:
# What is by saite he shall to breathes. Appitess as the due;
# I door it but to divill to; another'd borne.
#
# PERDITA:
#
# Epoch 19, batch 1500: loss=1.4087944030761719
# Epoch 19, batch 1510: loss=1.502343773841858
# Epoch 19, batch 1520: loss=1.4855748414993286
# Epoch 19, batch 1530: loss=1.4716753959655762
# Epoch 19, batch 1540: loss=1.5157232284545898
# Epoch 19, batch 1550: loss=1.5268886089324951
# Epoch 19, batch 1560: loss=1.4185810089111328
# Epoch 19, batch 1570: loss=1.5253221988677979
# Epoch 19, batch 1580: loss=1.4587266445159912
# Epoch 19, batch 1590: loss=1.3661227226257324
# Epoch 19, batch 1600: loss=1.5323271751403809
# Epoch 19, batch 1610: loss=1.5282835960388184
# Epoch 19, batch 1620: loss=1.458721399307251
# Epoch 19, batch 1630: loss=1.4925732612609863
# Epoch 19, batch 1640: loss=1.5205974578857422
# Epoch 19, batch 1650: loss=1.5141388177871704
# Epoch 19, batch 1660: loss=1.4021075963974
# Epoch 19, batch 1670: loss=1.4598413705825806
# Epoch 19, batch 1680: loss=1.4464023113250732
# Epoch 19, batch 1690: loss=1.5124139785766602
# Epoch 19, batch 1700: loss=1.5144546031951904
# Epoch 19, batch 1710: loss=1.367417573928833
# Epoch 19, batch 1720: loss=1.3438971042633057
# Epoch 19, batch 1730: loss=1.4661076068878174
# Epoch 19, batch 1740: loss=1.4881548881530762
# Epoch 19, batch 1750: loss=1.605196237564087
# Epoch 19, batch 1760: loss=1.551159143447876
# Epoch 19, batch 1770: loss=1.4429082870483398
# Epoch 19, batch 1780: loss=1.4861972332000732
# Epoch 19, batch 1790: loss=1.4526982307434082
# Epoch 19, batch 1800: loss=1.537421703338623
# Epoch 19, batch 1810: loss=1.6109951734542847
# Epoch 19, batch 1820: loss=1.422759771347046
# Epoch 19, batch 1830: loss=1.458481788635254
# Epoch 19, batch 1840: loss=1.4476898908615112
# Epoch 19, batch 1850: loss=1.4996312856674194
# Epoch 19, batch 1860: loss=1.5758166313171387
# Epoch 19, batch 1870: loss=1.4658653736114502
# Epoch 19, batch 1880: loss=1.4007946252822876
# Epoch 19, batch 1890: loss=1.4055240154266357
# Epoch 19, batch 1900: loss=1.532212734222412
# Epoch 19, batch 1910: loss=1.4409680366516113
# Epoch 19, batch 1920: loss=1.5493385791778564
# Epoch 19, batch 1930: loss=1.5411655902862549
# Epoch 19, batch 1940: loss=1.4691507816314697
# Epoch 19, batch 1950: loss=1.4678033590316772
# Epoch 19, batch 1960: loss=1.4349324703216553
# Epoch 19, batch 1970: loss=1.4749715328216553
# Epoch 19, batch 1980: loss=1.492179274559021
# Epoch 19, batch 1990: loss=1.4230328798294067
#
#
# Nurse:
# Hang stetch me, or my without to sweet
# Wys any livive dreams; star'd by this.
# Here, luck'd battle a
# but he maid at revel you gentle srown light Ladio.
#
# ANGELO:
# Well'd him, I shall have you are do that your name,
# Both father and other dream both,
# You me even the eyes--for
# This gappersiticlan: cor yoe that in me before along gift'd
# Brinkand sirs himself itful it your habhe;
# And pawn'd up crite I double
# I art the plowers, and banot
# Apparels as repetted not, but alligence yet dead
# Where's us as warrave my goddles quiet myself?
# Have it brain'd thee warrant saick,
# I exdise land death: so it their in thy gracious ab wedit of the neever
# Provise horse to my call're dead with here;
# For, by fit om bather hence, then from her in mon hither?
#
# Offie, who little:
# Belive! thouse Dick! This branething?
# Planture not movides, the is an little their more. I have drows,
# Shall not a master, but Murderer:
# For her spirit; I am tell thee womb!
# Where I set hear and these need thee said that word man, the
#
# Epoch 19, batch 2000: loss=1.4938334226608276
# Epoch 19, batch 2010: loss=1.321840763092041
# Epoch 19, batch 2020: loss=1.4276280403137207
# Epoch 19, batch 2030: loss=1.4379653930664062
# Epoch 19, batch 2040: loss=1.4457461833953857
# Epoch 19, batch 2050: loss=1.4877041578292847
# Epoch 19, batch 2060: loss=1.4462766647338867
# Epoch 19, batch 2070: loss=1.377110242843628
# Epoch 19, batch 2080: loss=1.4689968824386597
# Epoch 19, batch 2090: loss=1.458748698234558
# Epoch 19, batch 2100: loss=1.4586797952651978
# Epoch 19, batch 2110: loss=1.4174931049346924
# Epoch 19, batch 2120: loss=1.4297077655792236
# Epoch 19, batch 2130: loss=1.4571499824523926
# Epoch 19, batch 2140: loss=1.526976466178894
# Epoch 19, batch 2150: loss=1.4018917083740234
# Epoch 19, batch 2160: loss=1.4723796844482422
# Epoch 19, batch 2170: loss=1.537302017211914
